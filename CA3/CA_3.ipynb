# %% [markdown]
# # CA3

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
# Out:
# /tmp/ipykernel_1727851/1512147784.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# /home/idris/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### Reading data

# %%
df = pd.read_csv('Assets/train.csv')
df
# Out:
#       Unnamed: 0  Acoustic Firmness Index  \
# 0              0                     28.7
# 1              1                     19.4
# 2              2                     22.1
# 3              3                     28.0
# 4              4                     22.6
# ...          ...                      ...
# 1243        1243                     16.8
# 1244        1244                     32.8
# 1245        1245                     13.6
# 1246        1246                     26.7
# 1247        1247                     22.1
#
#       Atmospheric Pressure at Harvest (Pa)  Bitterness Scale  \
# 0                                  98741.0               0.0
# 1                                  96077.0               0.0
# 2                                 109154.0               2.0
# 3                                 105277.0               5.0
# 4                                 103898.0               2.0
# ...                                    ...               ...
# 1243                               99423.0               0.0
# 1244                               97732.0               1.0
# 1245                               93981.0               0.0
# 1246                               98269.0               1.0
# 1247                               97859.0               5.0
#
#       Circumference (mm)  Color Intensity (a.u.)  \
# 0             222.897985                   70.28
# 1             205.832386                   66.48
# 2             234.406576                   69.92
# 3             214.999623                   64.05
# 4             180.542626                   53.63
# ...                  ...                     ...
# 1243          212.988102                   61.08
# 1244          216.074798                   76.20
# 1245          181.435023                   69.64
# 1246          228.399719                   76.16
# 1247          216.998582                   60.51
#
#       Find Distance from Main Vulcano (km)  Length (mm)  \
# 0                               103.145212    35.481123
# 1                               102.005624    32.609013
# 2                                37.847317    37.926057
# 3                               100.118399    34.610539
# 4                                63.590438    28.948902
# ...                                    ...          ...
# 1243                             40.910882    33.728356
# 1244                             19.335461    34.925058
# 1245                             48.416290    29.071256
# 1246                             46.333693    37.776037
# 1247                             41.436860    34.110667
#
#       Luminescence Intensity (a.u.)  Magnetic orientation (degree)  \
# 0                          0.002636                      61.877407
# 1                          0.015950                     297.191998
# 2                          0.000279                      61.103057
# 3                          0.002323                      58.677047
# 4                          0.008611                     317.261190
# ...                             ...                            ...
# 1243                       0.003155                     195.342578
# 1244                       0.001954                     167.035722
# 1245                       0.000355                     118.170049
# 1246                       0.002577                     217.742170
# 1247                       0.004412                     273.181629
#
#       Odor index (a.u.)  Seed Count  Skin Thickness (mm)  Soil pH where Grown  \
# 0              2.700236   71.355713                  2.5                 8.14
# 1              9.618586   46.291493                  2.0                 7.63
# 2              7.970050   54.442385                  1.5                 8.03
# 3             68.116450  106.401880                  4.5                 7.43
# 4              7.953544   48.057754                  5.0                 6.71
# ...                 ...         ...                  ...                  ...
# 1243          25.475841    7.033815                  3.5                 6.67
# 1244          92.206845   51.766716                  4.0                 6.50
# 1245           7.579661    7.756912                  2.0                 6.99
# 1246          14.873524   66.630218                  2.0                 6.95
# 1247           5.358997   71.383990                  3.0                 7.34
#
#       Sugar Content (mg)  Weight (mg)        pH  Edible
# 0                13792.0   87411.1826  5.090000     1.0
# 1                12985.0   72608.1826  4.990000     1.0
# 2                10008.0  109375.1826  5.219156     0.0
# 3                11303.0   84958.7826  3.228828     0.0
# 4                11475.0   49717.1826  4.800000     1.0
# ...                  ...          ...       ...     ...
# 1243             12224.0   77045.1826  5.000000     1.0
# 1244              9626.0   87212.3826  5.332933     0.0
# 1245             10423.0   51560.1826  4.880000     1.0
# 1246              6753.0  105907.1826  3.383773     0.0
# 1247             12304.0   74321.9826  3.686011     0.0
#
# [1248 rows x 18 columns]

# %% [markdown]
# ### Data exploration and visualisation

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Unnamed: 0  Acoustic Firmness Index  \
# 9              9                     18.6
# 25            25                     25.3
# 135          135                     24.4
# 161          161                     21.8
# 190          190                     21.0
# 203          203                     31.4
# 237          237                     16.6
# 280          280                     27.3
# 330          330                      6.2
# 354          354                     18.0
# 411          411                     11.8
# 422          422                     23.0
# 434          434                      NaN
# 440          440                      NaN
# 450          450                     25.0
# 474          474                     20.6
# 557          557                     24.7
# 568          568                     13.6
# 585          585                      7.6
# 761          761                     12.7
# 788          788                     17.3
# 810          810                     23.0
# 827          827                     15.8
# 859          859                      NaN
# 896          896                     14.0
# 915          915                     19.9
# 970          970                     31.3
# 986          986                     12.8
# 1009        1009                     23.7
# 1033        1033                     20.3
# 1063        1063                     27.0
# 1105        1105                     17.7
# 1124        1124                     15.8
# 1132        1132                     21.9
# 1146        1146                     18.4
# 1162        1162                     20.4
# 1212        1212                     22.6
#
#       Atmospheric Pressure at Harvest (Pa)  Bitterness Scale  \
# 9                                  98441.0               NaN
# 25                                102300.0               4.0
# 135                                98459.0               0.0
# 161                                97338.0               2.0
# 190                               109623.0               0.0
# 203                               110062.0               6.0
# 237                               106015.0               4.0
# 280                               101351.0               2.0
# 330                               100398.0               0.0
# 354                                95815.0               0.0
# 411                               103065.0               4.0
# 422                                98213.0               NaN
# 434                               103487.0               4.0
# 440                               100351.0               0.0
# 450                                99958.0               2.0
# 474                                97311.0               0.0
# 557                               103056.0               4.0
# 568                                96623.0               1.0
# 585                                98346.0               1.0
# 761                                97565.0               3.0
# 788                                95421.0               3.0
# 810                               102198.0               0.0
# 827                               109257.0               3.0
# 859                                98582.0               0.0
# 896                                98721.0               5.0
# 915                               102155.0               2.0
# 970                               104463.0               1.0
# 986                               103134.0               1.0
# 1009                              101788.0               1.0
# 1033                               90924.0               0.0
# 1063                              101195.0               3.0
# 1105                              103471.0               NaN
# 1124                              102290.0               NaN
# 1132                              101497.0               2.0
# 1146                               98481.0               2.0
# 1162                              106357.0               1.0
# 1212                              102717.0               1.0
#
#       Circumference (mm)  Color Intensity (a.u.)  \
# 9             193.742185                   56.51
# 25            190.527909                   60.61
# 135           217.066116                   56.70
# 161           196.793798                   64.13
# 190           217.672365                   58.28
# 203           247.568906                   70.78
# 237           223.744843                   62.78
# 280           245.449299                   62.16
# 330           218.614502                   62.09
# 354           210.940636                   62.55
# 411           226.188200                   81.36
# 422           191.714105                   60.34
# 434           188.322992                   55.76
# 440           162.971214                   60.46
# 450                  NaN                   66.92
# 474           213.961499                   56.04
# 557           248.559479                   73.22
# 568           147.912611                   72.40
# 585           171.635520                   88.89
# 761           215.217767                   76.75
# 788           244.434093                   64.32
# 810           217.929700                   56.76
# 827           222.373678                   83.53
# 859           214.689279                   55.94
# 896           211.831280                   63.53
# 915           218.172347                   60.58
# 970           253.669400                   71.81
# 986           220.724250                   65.83
# 1009                 NaN                   58.63
# 1033          213.938035                   69.95
# 1063          224.896956                   56.85
# 1105          170.113774                   63.58
# 1124          210.795330                   60.26
# 1132          216.742020                   59.52
# 1146          217.577700                   55.32
# 1162          230.559923                   64.53
# 1212          240.215622                   65.03
#
# Sugar Content (mg)                      3
# Weight (mg)                             4
# pH                                      4
# Edible                                  0
# dtype: int64

# %%
# Checking what the shape and what are the datatypes we are working
print("The shape of the data: ", df.shape)
print()
print("The datatypes in each column are: ", df.dtypes)
# Out:
# The shape of the data:  (1248, 18)
#
# The datatypes in each column are:  Unnamed: 0                                int64
# Acoustic Firmness Index                 float64
# Atmospheric Pressure at Harvest (Pa)    float64
# Bitterness Scale                        float64
# Circumference (mm)                      float64
# Color Intensity (a.u.)                  float64
# Find Distance from Main Vulcano (km)    float64
# Length (mm)                             float64
# Luminescence Intensity (a.u.)           float64
# Magnetic orientation (degree)           float64
# Odor index (a.u.)                       float64
# Seed Count                              float64
# Skin Thickness (mm)                     float64
# Soil pH where Grown                     float64
# Sugar Content (mg)                      float64
# Weight (mg)                             float64
# pH                                      float64
# Edible                                  float64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0  Acoustic Firmness Index  \
# count  1248.000000              1245.000000
# mean    623.500000                21.570077
# std     360.410877                 8.131888
# min       0.000000                 0.600000
# 25%     311.750000                17.300000
# 50%     623.500000                21.300000
# 75%     935.250000                25.300000
# max    1247.000000               156.520701
#
#        Atmospheric Pressure at Harvest (Pa)  Bitterness Scale  \
# count                           1248.000000       1244.000000
# mean                          101327.543269          1.808682
# std                             4772.582203          1.960279
# min                            83825.000000          0.000000
# 25%                            98095.750000          0.000000
# 50%                           101357.000000          1.000000
# 75%                           104470.750000          3.000000
# max                           115636.000000          7.000000
#
#        Circumference (mm)  Color Intensity (a.u.)  \
# count         1246.000000             1248.000000
# mean           211.046062               63.300962
# std             24.652278                7.118135
# min            145.867667               46.060000
# 25%            192.982222               58.577500
# 50%            212.429730               62.390000
# 75%            226.313333               67.202500
# max            274.719407               97.810000
#
#        Find Distance from Main Vulcano (km)  Length (mm)  \
# count                           1246.000000  1244.000000
# mean                              44.188204    33.589646
# std                               28.331532     3.874355
# min                                2.550790    23.451799
# 25%                               21.203453    30.777936
# 50%                               38.880858    33.784401
# 75%                               60.680816    36.049083
# max                              109.952511    43.691515
#
#        Luminescence Intensity (a.u.)  Magnetic orientation (degree)  \
# count                    1247.000000                    1245.000000
# mean                        0.002850                     178.933737
# std                         0.003607                     102.113321
# min                         0.000004                       0.085357
# 25%                         0.000627                      90.582930
# 50%                         0.001757                     180.043851
# 75%                         0.003767                     266.481765
# max                         0.044624                     359.443812
#
#        Odor index (a.u.)   Seed Count  Skin Thickness (mm)  \
# count        1246.000000  1247.000000          1247.000000
# mean           16.602442    48.926812             3.839615
# std            14.882420    35.871733             1.483029
# min             1.722825     0.000000             1.000000
# 25%             7.615908    15.852008             3.000000
# 50%            12.258785    47.932723             4.000000
# 75%            20.302048    80.413165             5.000000
# max           152.041780   112.968004             8.500000
#
#        Soil pH where Grown  Sugar Content (mg)    Weight (mg)           pH  \
# count          1245.000000         1245.000000    1244.000000  1244.000000
# mean              7.278739        11835.978313   78446.779224     4.614780
# std               0.529815         2417.733775   26637.766132     0.993407
# min               5.710000         4566.000000   32352.182600    -5.120000
# 25%               6.910000        10353.000000   57087.682600     4.174979
# 50%               7.280000        11807.000000   77440.682600     4.910000
# 75%               7.660000        13534.000000   92664.102600     5.080000
# max               8.980000        18246.000000  164679.342600     6.081918
#
#             Edible
# count  1248.000000
# mean      0.494391
# std       0.500169
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
# Cheking edible vs non edible
plt.figure(figsize=(10, 6))
sns.countplot(x='Edible', data=df, palette="Set2", hue='Edible')
plt.title('Distrubution of Edible')
plt.xlabel('Ediblity')
plt.ylabel('count')
plt.show()

# %%
# Creates plots of distribution
def plot_dist(df, column_names):
    plt.figure(figsize=(32,24))
    
    for i in range(1, len(column_names)-1):
        plt.subplot(4, 4, i)
        sns.histplot(df[column_names[i]], bins=20, kde=True)
        plt.title('Distrubution of {0}'.format(column_names[i]))
        
    # plt.tight_layout()
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.9)
    plt.show()

# %%
# I want to see the distribution for all of the columns in our dataset
column_names = df.columns
plot_dist(df, column_names)

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# Since there is some missing data, I will write some code in order to remove those follwing rows with the missing information.

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Unnamed: 0                              0
# Acoustic Firmness Index                 0
# Atmospheric Pressure at Harvest (Pa)    0
# Bitterness Scale                        0
# Circumference (mm)                      0
# Color Intensity (a.u.)                  0
# Find Distance from Main Vulcano (km)    0
# Length (mm)                             0
# Luminescence Intensity (a.u.)           0
# Magnetic orientation (degree)           0
# Odor index (a.u.)                       0
# Seed Count                              0
# Skin Thickness (mm)                     0
# Soil pH where Grown                     0
# Sugar Content (mg)                      0
# Weight (mg)                             0
# pH                                      0
# Edible                                  0
# dtype: int64

# %% [markdown]
# Removing outliers:

# %%
z_scores = (df - np.mean(df, axis=0)) / np.std(df, axis=0)
outliers = np.abs(z_scores) > 3
df[~outliers]
# Out:
#       Unnamed: 0  Acoustic Firmness Index  \
# 0              0                     28.7
# 1              1                     19.4
# 2              2                     22.1
# 3              3                     28.0
# 4              4                     22.6
# ...          ...                      ...
# 1243        1243                     16.8
# 1244        1244                     32.8
# 1245        1245                     13.6
# 1246        1246                     26.7
# 1247        1247                     22.1
#
#       Atmospheric Pressure at Harvest (Pa)  Bitterness Scale  \
# 0                                  98741.0               0.0
# 1                                  96077.0               0.0
# 2                                 109154.0               2.0
# 3                                 105277.0               5.0
# 4                                 103898.0               2.0
# ...                                    ...               ...
# 1243                               99423.0               0.0
# 1244                               97732.0               1.0
# 1245                               93981.0               0.0
# 1246                               98269.0               1.0
# 1247                               97859.0               5.0
#
#       Circumference (mm)  Color Intensity (a.u.)  \
# 0             222.897985                   70.28
# 1             205.832386                   66.48
# 2             234.406576                   69.92
# 3             214.999623                   64.05
# 4             180.542626                   53.63
# ...                  ...                     ...
# 1243          212.988102                   61.08
# 1244          216.074798                   76.20
# 1245          181.435023                   69.64
# 1246          228.399719                   76.16
# 1247          216.998582                   60.51
#
#       Find Distance from Main Vulcano (km)  Length (mm)  \
# 0                               103.145212    35.481123
# 1                               102.005624    32.609013
# 2                                37.847317    37.926057
# 3                               100.118399    34.610539
# 4                                63.590438    28.948902
# ...                                    ...          ...
# 1243                             40.910882    33.728356
# 1244                             19.335461    34.925058
# 1245                             48.416290    29.071256
# 1246                             46.333693    37.776037
# 1247                             41.436860    34.110667
#
#       Luminescence Intensity (a.u.)  Magnetic orientation (degree)  \
# 0                          0.002636                      61.877407
# 1                               NaN                     297.191998
# 2                          0.000279                      61.103057
# 3                          0.002323                      58.677047
# 4                          0.008611                     317.261190
# ...                             ...                            ...
# 1243                       0.003155                     195.342578
# 1244                       0.001954                     167.035722
# 1245                       0.000355                     118.170049
# 1246                       0.002577                     217.742170
# 1247                       0.004412                     273.181629
#
#       Odor index (a.u.)  Seed Count  Skin Thickness (mm)  Soil pH where Grown  \
# 0              2.700236   71.355713                  2.5                 8.14
# 1              9.618586   46.291493                  2.0                 7.63
# 2              7.970050   54.442385                  1.5                 8.03
# 3                   NaN  106.401880                  4.5                 7.43
# 4              7.953544   48.057754                  5.0                 6.71
# ...                 ...         ...                  ...                  ...
# 1243          25.475841    7.033815                  3.5                 6.67
# 1244                NaN   51.766716                  4.0                 6.50
# 1245           7.579661    7.756912                  2.0                 6.99
# 1246          14.873524   66.630218                  2.0                 6.95
# 1247           5.358997   71.383990                  3.0                 7.34
#
#       Sugar Content (mg)  Weight (mg)        pH  Edible
# 0                13792.0   87411.1826  5.090000     1.0
# 1                12985.0   72608.1826  4.990000     1.0
# 2                10008.0  109375.1826  5.219156     0.0
# 3                11303.0   84958.7826  3.228828     0.0
# 4                11475.0   49717.1826  4.800000     1.0
# ...                  ...          ...       ...     ...
# 1243             12224.0   77045.1826  5.000000     1.0
# 1244              9626.0   87212.3826  5.332933     0.0
# 1245             10423.0   51560.1826  4.880000     1.0
# 1246              6753.0  105907.1826  3.383773     0.0
# 1247             12304.0   74321.9826  3.686011     0.0
#
# [1211 rows x 18 columns]

# %%
column_names = df.columns
plot_dist(df, column_names)

# %% [markdown]
# ### Data preprocessing and visualisation

# %%
# Separating our feautures from the targets 
X = df.drop(columns=['Edible'])
y = df['Edible']

y = y.to_numpy().ravel()

# %% [markdown]
# ### Modelling

# %%
n_estimators_vals = [100, 150, 250, 350, 450, 500]
max_depth_vals = [None, 10, 20]
min_samples_split_vals = [6, 12, 16]


best_params = {}
best_acc = 0

for n in n_estimators_vals:
    for max_d in max_depth_vals:
        for min_ss in min_samples_split_vals:
            
            accuracies = []
            for r in range(20):

                X_train, X_val, y_train, y_val = train_test_split(X, y, 
                                                                  test_size=0.25, 
                                                                  random_state=r)
                scaler = StandardScaler()
                X_train_scaled = scaler.fit_transform(X_train)
                X_val_scaled = scaler.transform(X_val)

                clf = RandomForestClassifier(n_estimators=n,
                                             random_state=r, 
                                             min_samples_split=min_ss,
                                             max_depth=max_d)
                clf.fit(X_train_scaled, y_train)

                y_pred = clf.predict(X_val_scaled)

                accuracy = accuracy_score(y_pred, y_val)
                accuracies.append(accuracy)

            accuracy = np.mean(accuracies)

            if accuracy > best_acc:
                best_acc = accuracy
                best_params = {'n_estimators': n,
                               'max_depth': max_d,
                               'min_samples_split': min_ss,
                               'random_state': r}

# %%
best_params
# Out:
# {'n_estimators': 150,
#  'max_depth': None,
#  'min_samples_split': 6,
#  'random_state': 19}

# %%
best_acc
# Out:
# 0.9009900990099009

# %%
clf = RandomForestClassifier(**best_params)
X_train_scaled = scaler.fit_transform(X)
clf.fit(X_train_scaled, y)
# Out:
# RandomForestClassifier(min_samples_split=6, n_estimators=150, random_state=19)

# %% [markdown]
# ### Final evaluation

# %%
X_test = pd.read_csv('Assets/test.csv')

X_test_scaled = scaler.transform(X_test)
y_pred = clf.predict(X_test_scaled)

# %% [markdown]
# ### Kaggle submission

# %%
y_csv = np.savetxt('y_pred.csv', np.dstack((np.arange(0, y_pred.size),y_pred))[0],"%d,%d", header="index,Edible", comments='')
